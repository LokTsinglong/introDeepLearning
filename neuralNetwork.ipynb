# %%
def step_function_old(x):
    if x>=0:
        return 1
    else:
        return 0

# %%
step_function_old(20)
# Out:
# 1

# %%
step_function_old(-20)
# Out:
# 0

# %%
#允许numpy数组作为输入的step_function
import numpy as np
def step_function(x):
    y=x>0
    return y.astype(np.int)

# %%
x=np.array([-1.0,1.0,2.0])
x
# Out:
# array([-1.,  1.,  2.])

# %%
y=x>0
y
#进行布尔判断
# Out:
# array([False,  True,  True])

# %%
y=y.astype(np.int)
y
#astype类型转换
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 y=y.astype(np.int)
#       2 y
#       3 #astype类型转换
#
# File d:\vscodeProjects\introDeepLearning\.venv\Lib\site-packages\numpy\__init__.py:791, in __getattr__(attr)
#     786     warnings.warn(
#     787         f"In the future `np.{attr}` will be defined as the "
#     788         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     790 if attr in __former_attrs__:
# --> 791     raise AttributeError(__former_attrs__[attr], name=None)
#     793 if attr in __expired_attributes__:
#     794     raise AttributeError(
#     795         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     796         f"{__expired_attributes__[attr]}",
#     797         name=None
#     798     )
#
# AttributeError: module 'numpy' has no attribute 'int'.
# ...

# %%
y=y.astype(int)
y
#np.int用法好像被deprecated了，改用int
# Out:
# array([0, 1, 1])

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/110.1 kB ? eta -:--:--
#      ---------- ---------------------------- 30.7/110.1 kB 1.3 MB/s eta 0:00:01
#      ---------- ---------------------------- 30.7/110.1 kB 1.3 MB/s eta 0:00:01
#      ---------- ---------------------------- 30.7/110.1 kB 1.3 MB/s eta 0:00:01
#      ----------------- ------------------- 51.2/110.1 kB 219.0 kB/s eta 0:00:01
#      ------------------------------------ 110.1/110.1 kB 491.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB 640.0 kB/s eta 0:00:13
#    ---------------------------------------- 0.0/8.1 MB 640.0 kB/s eta 0:00:13
#    ---------------------------------------- 0.1/8.1 MB 363.1 kB/s eta 0:00:23
#     --------------------------------------- 0.1/8.1 MB 467.6 kB/s eta 0:00:18
# ...

# %%
#绘制出阶跃函数的图像
import matplotlib.pylab as plt
def step_function(x):
    return np.array(x>0,dtype=int)
    #int直接用就好了，不需要np.int了
x=np.arange(-5.,5.,0.1)
y=step_function(x)
plt.plot(x,y)
plt.ylim(-0.1,1.1)
plt.show()

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
x=np.array([-1.,1.,2.])
y=sigmoid(x)
y
# Out:
# array([0.26894142, 0.73105858, 0.88079708])

# %%
#numpy的广播功能
#标量会和numpy数组各个元素进行运算
t=np.array([1.,2.,3.])
1.+t
# Out:
# array([2., 3., 4.])

# %%
1./t
# Out:
# array([1.        , 0.5       , 0.33333333])

# %%
x=np.array([-5.,5.,0.1])
# 注意：x=np.array(-5.,5.,0.1)和 x=np.array([-5.,5.,0.5])是不同的
#前者是一个标量，后者是一个数组
y = sigmoid(x)
plt.plot(x,y)
plt.ylim(-.1,1.1)
plt.show()

# %%
x=np.arange(-5.,5.,0.1)
y = sigmoid(x)
plt.plot(x,y)
plt.ylim(-.1,1.1)
plt.show()

# %%
#Rectified Linear Unit ReLU函数构造
def relu(x):
    return np.maximum(0,x)
#最大值函数，返回两个数中较大的一个

# %%
x=np.arange(-5.,5.,0.1)
y=relu(x)
plt.plot(x,y)
plt.ylim(-.1,5.1)
plt.show()

# %%
import numpy as np
A = np.array([1,2,3,4])
print(A)
# Out:
# [1 2 3 4]

# %%
np.ndim(A)
# Out:
# 1

# %%
A.shape
# Out:
# (4,)

# %%
A.shape[0]
# Out:
# 4

# %%
A.shape[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 A.shape[1]
#
# IndexError: tuple index out of range

# %%
B=np.array([[1,2],[3,4],[5,6]])
print(B)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
np.ndim(B)
# Out:
# 2

# %%
B.shape
# Out:
# (3, 2)

# %% [markdown]
# B.shape 返回的是一个元组 tuple

# %%
#利用矩阵的点乘实现神经网络的运算
X=np.array([1,2])
X.shape
# Out:
# (2,)

# %%
W=np.array([[1,3,5],[2,4,6]])
print(W)
# Out:
# [[1 3 5]
#  [2 4 6]]

# %%
W.shape
# Out:
# (2, 3)

# %%
Y=np.dot(X,W)
Y
# Out:
# array([ 5, 11, 17])

# %%
X=np.array([1.0,0.5])
W1=np.array([[.1,.3,.5],[.2,.4,.6]])
B1=np.array([.1,.2,.3])
print(W1.shape)
print(X.shape)
print(B1.shape)
# Out:
# (2, 3)
# (2,)
# (3,)

# %%
A1=np.dot(X,W1)+B1
A1
# Out:
# array([0.3, 0.7, 1.1])

# %% [markdown]
# 这时还没经过激活函数处理的矩阵点乘的结果A1

# %%
Z1=sigmoid(A1)
Z1
# Out:
# array([0.57444252, 0.66818777, 0.75026011])

# %%
W2=np.array([[.1,.4,],[.2,.5],[.3,.6]])
B2=np.array([.1,.2])

print(Z1.shape)
print(W2.shape)
print(B2.shape)
# Out:
# (3,)
# (3, 2)
# (2,)

# %%
A2=np.dot(Z1,W2)+B2
Z2=sigmoid(A2)
Z2
# Out:
# array([0.62624937, 0.7710107 ])

# %%
def identity_function(x):
    return x

W3=np.array([[.1,.3],[.2,.4]])
B3=np.array([.1,.2])
A3=np.dot(Z2,W3)+B3
Y=identity_function(A3)
Y
# Out:
# array([0.31682708, 0.69627909])

# %%
def init_network():
    network={}
    network['W1']=np.array([[.1,.3,.5],[.2,.4,.6]])
    network['b1']=np.array([.1,.2,.3])
    network['W2']=np.array([[.1,.4],[.2,.5],[.3,.6]])
    network['b2']=np.array([.1,.2])
    network['W3']=np.array([[.1,.3],[.2,.4]])
    network['b3']=np.array([.1,.2])

    return network

# %%
def forward(network,x):
    W1,W2,W3 = network['W1'],network['W2'],network['W3']
    b1,b2,b3=network['b1'],network['b2'],network['b3']

    a1=np.dot(x,W1)+b1
    z1=sigmoid(a1)
    a2=np.dot(z1,W2)+b2
    z2=sigmoid(a2)
    a3=np.dot(z2,W3)+b3
    y=identity_function(a3)

    return y

# %%
network=init_network()
x=np.array([1.,.5])
y=forward(network,x)
print(y)
# Out:
# [0.31682708 0.69627909]

# %%
a=np.array([.3,2.9,4.0])
exp_a=np.exp(a)
print(exp_a)
# Out:
# [ 1.34985881 18.17414537 54.59815003]

# %%
sum_exp_a=np.sum(exp_a)
print(sum_exp_a)
# Out:
# 74.1221542101633

# %%
y=exp_a/sum_exp_a
print(y)
# Out:
# [0.01821127 0.24519181 0.73659691]

# %%
def softmax(a):
    c=np.max(a)
    exp_a=np.exp(a-c)
    sum_exp_a=np.sum(exp_a)
    y=exp_a/sum_exp_a
    return y

# %%
a=np.array([.3,2.9,4.0])
y=softmax(a)
print(y)
# Out:
# [0.01821127 0.24519181 0.73659691]

# %%
np.sum(y)
# Out:
# np.float64(1.0)

# %%
# !pip install keras
# Out:
# ...
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.4 MB 660.6 kB/s eta 0:00:03
#     --------------------------------------- 0.0/1.4 MB 660.6 kB/s eta 0:00:03
#     --------------------------------------- 0.0/1.4 MB 660.6 kB/s eta 0:00:03
#    --- ------------------------------------ 0.1/1.4 MB 547.6 kB/s eta 0:00:03
#    --- ------------------------------------ 0.1/1.4 MB 450.6 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.1/1.4 MB 448.2 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.4 MB 437.1 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.2/1.4 MB 419.0 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.2/1.4 MB 436.8 kB/s eta 0:00:03
# ...

# %%
# !pip install dataset
# Out:
# ...
#   Using cached mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# ...
#    ---------------------------------------- 0.0/247.0 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/247.0 kB 1.4 MB/s eta 0:00:01
#    ------ -------------------------------- 41.0/247.0 kB 495.5 kB/s eta 0:00:01
#    ------ -------------------------------- 41.0/247.0 kB 495.5 kB/s eta 0:00:01
#    ---------------------- --------------- 143.4/247.0 kB 774.0 kB/s eta 0:00:01
#    ---------------------- --------------- 143.4/247.0 kB 774.0 kB/s eta 0:00:01
#    ----------------------------- -------- 194.6/247.0 kB 695.5 kB/s eta 0:00:01
#    -------------------------------------  245.8/247.0 kB 793.0 kB/s eta 0:00:01
#    -------------------------------------- 247.0/247.0 kB 758.9 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
# ...

# %%
#MNIST数据集
from dataset.mnist import mnist
(x_train,t_train),(x_test,t_test)=mnist.load_data()
print(x_train.shape)
print(t_train.shape)
print(x_test.shape)
print(t_test.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[61], line 2
#       1 #MNIST数据集
# ----> 2 from dataset.mnist import mnist
#       3 (x_train,t_train),(x_test,t_test)=mnist.load_data()
#       4 print(x_train.shape)
#
# ModuleNotFoundError: No module named 'dataset.mnist'

# %% [markdown]
# 因为书里面的dataset模块需要专门从github上面下载下来

# %%
# !pip install tensorflow
# Out:
# ^C

# %%
# !pip install tensorflow keras
# Out:
# ^C

# %% [markdown]
# 这个tensorflow keras太大了，下载的时间太久了，所以想还是换一种方式:利用sklearn的包

# %%
# !pip install sklearn
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
# ...

# %%
# !pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.9 MB 660.6 kB/s eta 0:00:14
#    ---------------------------------------- 0.0/8.9 MB 487.6 kB/s eta 0:00:19
#    ---------------------------------------- 0.1/8.9 MB 465.5 kB/s eta 0:00:20
#    ---------------------------------------- 0.1/8.9 MB 465.5 kB/s eta 0:00:20
#    ---------------------------------------- 0.1/8.9 MB 374.1 kB/s eta 0:00:24
#    ---------------------------------------- 0.1/8.9 MB 374.1 kB/s eta 0:00:24
# ...

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB 1.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.1/11.3 MB 787.7 kB/s eta 0:00:15
#     --------------------------------------- 0.1/11.3 MB 1.1 MB/s eta 0:00:11
#     --------------------------------------- 0.2/11.3 MB 1.0 MB/s eta 0:00:12
#    - -------------------------------------- 0.3/11.3 MB 1.4 MB/s eta 0:00:09
#    - -------------------------------------- 0.4/11.3 MB 1.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/11.3 MB 1.7 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/11.3 MB 1.8 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/11.3 MB 1.8 MB/s eta 0:00:07
# ...
